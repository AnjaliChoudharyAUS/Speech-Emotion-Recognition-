# %% [markdown]
# <a href="https://colab.research.google.com/github/AnjaliChoudharyAUS/Speech-Emotion-Recognition-/blob/main/baseline_model_fulldata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os,glob
import librosa 
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import warnings; warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/MyDrive/RAVDESS.zip' .
# !unzip -q RAVDESS.zip

# %%
sample_rate=48000
def feature_melspectrogram(
    waveform, 
    sample_rate,
    fft = 1024,
    winlen = 512,
    window='hamming',
    hop=256,
    mels=128,
    ):
    
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram = librosa.feature.melspectrogram(
        y=waveform, 
        sr=sample_rate, 
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2)
    
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    melspectrogram = librosa.power_to_db(melspectrogram, ref=np.max)
    
    return melspectrogram

def feature_mfcc(
    waveform, 
    sample_rate,
    n_mfcc = 40,
    fft = 1024,
    winlen = 512,
    window='hamming',
    #hop=256, # increases # of time steps; was not helpful
    mels=128
    ):

    # Compute the MFCCs for all STFT frames 
    # 40 mel filterbanks (n_mfcc) = 40 coefficients
    mfc_coefficients=librosa.feature.mfcc(
        y=waveform, 
        sr=sample_rate, 
        n_mfcc=n_mfcc,
        n_fft=fft, 
        win_length=winlen, 
        window=window, 
        #hop_length=hop, 
        n_mels=mels, 
        fmax=sample_rate/2
        ) 

    return mfc_coefficients

def get_features(waveforms, features, samplerate):

    # initialize counter to track progress
    file_count = 0

    # process each waveform individually to get its MFCCs
    for waveform in waveforms:
        mfccs = feature_mfcc(waveform, sample_rate)
        features.append(mfccs)
        file_count += 1
        
        # print progress 
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
    
    # return all features from list of waveforms
    return features

def get_waveforms(file):
    
    # load an individual sample audio file
    # read the full 3 seconds of the file, cut off the first 0.5s of silence; native sample rate = 48k
    # don't need to store the sample rate that librosa.load returns
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # make sure waveform vectors are homogenous by defining explicitly
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return a single file's waveform                                      
    return waveform_homo
    
# RAVDESS dataset emotions
# shift emotions left to be 0 indexed for PyTorch
emotions_dict ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# Additional attributes from RAVDESS to play with
emotion_attributes = {
    '01': 'normal',
    '02': 'strong'
}

# %%
data_path='./Actor_*/*.wav' 
def load_data():
  print('hlo')
  emotions=[]
  waveforms=[]
  intensities,genders=[],[]
  file_count=0
  for file in glob.glob(data_path):
    file_name=os.path.basename(file)
    emotion=int(file_name.split("-")[2])
    if emotion==8: emotion=0
    intensity=emotion_attributes[file_name.split("-")[3]]
    if(int((file_name.split("-")[6]).split(".")[0]))%2==0:
      gender='female'
    else:
      gender='male'
    waveform=get_waveforms(file)
    waveforms.append(waveform)
    emotions.append(emotion)
    intensities.append(intensity)
    genders.append(gender)
    file_count+=1
    print('\r'+f' Processed{file_count}/{1440} audio samples',end='')
  return waveforms, emotions, intensities, genders

# %%
waveforms,emotions,intensities,genders=[],[],[],[]
waveforms,emotions,intensities, genders=load_data()
# Out:
# hlo
#  Processed1440/1440 audio samples

# %%
print(f'Waveforms set: {len(waveforms)} samples')

print(f'Waveform signal length: {len(waveforms[0])}')
print(f'Emotions set: {len(emotions)} sample labels')
# Out:
# Waveforms set: 1440 samples
# Waveform signal length: 144000
# Emotions set: 1440 sample labels

# %%
train_set, valid_set, test_set=[],[],[]
X_train,X_valid,X_test=[],[],[]
y_train,y_valid,y_test = [],[],[]
waveforms=np.array(waveforms)
for emotion_num in range(len(emotions_dict)):
  emotion_indices=[index for index, emotion in enumerate(emotions) if emotion==emotion_num]
  np.random.seed(69)
  emotion_indices=np.random.permutation(emotion_indices)
  dim=len(emotion_indices)
    # train set is first 80%
  train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
  valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
  test_indices = emotion_indices[int(0.9*dim):]

  X_train.append(waveforms[train_indices,:])
  y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
  X_valid.append(waveforms[valid_indices,:])
  y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
  X_test.append(waveforms[test_indices,:])
  y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
  train_set.append(train_indices)
  valid_set.append(valid_indices)
  test_set.append(test_indices)
# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

uniques, count=np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %%
train_set, valid_set, test_set=[],[],[]
X_train,X_valid,X_test=[],[],[]
y_train,y_valid,y_test = [],[],[]
waveforms=np.array(waveforms)
for emotion_num in range(len(emotions_dict)):
  emotion_indices=[index for index, emotion in enumerate(emotions) if emotion==emotion_num]
  np.random.seed(69)
  emotion_indices=np.random.permutation(emotion_indices)
  dim=len(emotion_indices)
    # train set is first 80%
  train_indices = emotion_indices[:int(0.8*dim)]
    # validation set is next 10% (between 80% and 90%)
  valid_indices = emotion_indices[int(0.8*dim):int(0.9*dim)]
    # test set is last 10% (between 90% - end/100%)
  test_indices = emotion_indices[int(0.9*dim):]

  X_train.append(waveforms[train_indices,:])
  y_train.append(np.array([emotion_num]*len(train_indices),dtype=np.int32))
    # create validation waveforms/labels sets
  X_valid.append(waveforms[valid_indices,:])
  y_valid.append(np.array([emotion_num]*len(valid_indices),dtype=np.int32))
    # create test waveforms/labels sets
  X_test.append(waveforms[test_indices,:])
  y_test.append(np.array([emotion_num]*len(test_indices),dtype=np.int32))

    # store indices for each emotion set to verify uniqueness between sets 
  train_set.append(train_indices)
  valid_set.append(valid_indices)
  test_set.append(test_indices)
# concatenate, in order, all waveforms back into one array 
X_train = np.concatenate(X_train,axis=0)
X_valid = np.concatenate(X_valid,axis=0)
X_test = np.concatenate(X_test,axis=0)

# concatenate, in order, all emotions back into one array 
y_train = np.concatenate(y_train,axis=0)
y_valid = np.concatenate(y_valid,axis=0)
y_test = np.concatenate(y_test,axis=0)

# combine and store indices for all emotions' train, validation, test sets to verify uniqueness of sets
train_set = np.concatenate(train_set,axis=0)
valid_set = np.concatenate(valid_set,axis=0)
test_set = np.concatenate(test_set,axis=0)

# check shape of each set
print(f'Training waveforms:{X_train.shape}, y_train:{y_train.shape}')
print(f'Validation waveforms:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'Test waveforms:{X_test.shape}, y_test:{y_test.shape}')

uniques, count=np.unique(np.concatenate([train_set,test_set,valid_set],axis=0), return_counts=True)
if sum(count==1) == len(emotions):
    print(f'\nSets are unique: {sum(count==1)} samples out of {len(emotions)} are unique')
else:
    print(f'\nSets are NOT unique: {sum(count==1)} samples out of {len(emotions)} are unique')
# Out:
# Training waveforms:(1147, 144000), y_train:(1147,)
# Validation waveforms:(143, 144000), y_valid:(143,)
# Test waveforms:(150, 144000), y_test:(150,)
#
# Sets are unique: 1440 samples out of 1440 are unique

# %%
# initialize feature arrays
# We extract MFCC features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = get_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = get_features(X_valid, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = get_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')

print(f'Features (MFC coefficient matrix) shape: {len(features_train[0])} mel frequency coefficients x {len(features_train[0][1])} time steps')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (MFC coefficient matrix) shape: 40 mel frequency coefficients x 282 time steps

# %%
plt.figure(figsize=(15,4))
plt.subplot(1, 2, 1)
librosa.display.waveshow(waveforms[12], sr=sample_rate)
plt.title('Native')
# Out:
# Text(0.5, 1.0, 'Native')

# %%
X_train = np.expand_dims(features_train, 1)
X_valid = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test, 1)


y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# confiorm that we have tensor-ready 4D data array
# should print (batch, channel, width, height) == (4320, 1, 128, 282) when multiples==2
print(f'Shape of 4D feature array for input tensor: {X_train.shape} train, {X_valid.shape} validation, {X_test.shape} test')
print(f'Shape of emotion labels: {y_train.shape} train, {y_valid.shape} validation, {y_test.shape} test')
# Out:
# Shape of 4D feature array for input tensor: (1147, 1, 40, 282) train, (143, 1, 40, 282) validation, (150, 1, 40, 282) test
# Shape of emotion labels: (1147,) train, (143,) validation, (150,) test

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#### Scale the training data ####
# store shape so we can transform it back 
N,C,H,W = X_train.shape
# Reshape to 1D because StandardScaler operates on a 1D array
# tell numpy to infer shape of 1D array with '-1' argument
X_train = np.reshape(X_train, (N,-1)) 
X_train = scaler.fit_transform(X_train)
# Transform back to NxCxHxW 4D tensor format
X_train = np.reshape(X_train, (N,C,H,W))

##### Scale the validation set ####
N,C,H,W = X_valid.shape
X_valid = np.reshape(X_valid, (N,-1))
X_valid = scaler.transform(X_valid)
X_valid = np.reshape(X_valid, (N,C,H,W))

#### Scale the test set ####
N,C,H,W = X_test.shape
X_test = np.reshape(X_test, (N,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, (N,C,H,W))

# check shape of each set again
print(f'X_train scaled:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid scaled:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test scaled:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train scaled:(1147, 1, 40, 282), y_train:(1147,)
# X_valid scaled:(143, 1, 40, 282), y_valid:(143,)
# X_test scaled:(150, 1, 40, 282), y_test:(150,)

# %%
filename = 'features+labels.npy'

# open file in write mode and write data
with open(filename, 'wb') as f:
    np.save(f, X_train)
    np.save(f, X_valid)
    np.save(f, X_test)
    np.save(f, y_train)
    np.save(f, y_valid)
    np.save(f, y_test)

print(f'Features and labels saved to {filename}')
# Out:
# Features and labels saved to features+labels.npy

# %%
filename = 'features+labels.npy'

# open file in read mode and read data 
with open(filename, 'rb') as f:
    X_train = np.load(f)
    X_valid = np.load(f)
    X_test = np.load(f)
    y_train = np.load(f)
    y_valid = np.load(f)
    y_test = np.load(f)

# Check that we've recovered the right data
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_valid:{X_valid.shape}, y_valid:{y_valid.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(1147, 1, 40, 282), y_train:(1147,)
# X_valid:(143, 1, 40, 282), y_valid:(143,)
# X_test:(150, 1, 40, 282), y_test:(150,)

# %%
class parallel_all_you_want(nn.Module):
    # Define all layers present in the network
    def __init__(self,num_emotions):
        super().__init__() 
        
        ################ TRANSFORMER BLOCK #############################
        # maxpool the input feature map/tensor to the transformer 
        # a rectangular kernel worked better here for the rectangular input spectrogram feature map/tensor
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        
        # define single transformer encoder layer
        # self-attention + feedforward network from "Attention is All You Need" paper
        # 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=40, # input feature (frequency) dim after maxpooling 40*282 -> 40*70 (MFC*time)
            nhead=4, # 4 self-attention layers in each multi-head self-attention layer in each encoder block
            dim_feedforward=512, # 2 linear layers in each encoder block's feedforward network: dim 40-->512--->40
            dropout=0.4, 
            activation='relu' # ReLU: avoid saturation/tame gradient/reduce compute time
        )
        
        # I'm using 4 instead of the 6 identical stacked encoder layrs used in Attention is All You Need paper
        # Complete transformer block contains 4 full transformer encoder layers (each w/ multihead self-attention+feedforward)
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=4)
        self.conv2Dblock1 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
            
            # 2nd 2D convolution layer identical to last except output dim, maxpool kernel
            nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
              nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        ############### 2ND PARALLEL 2D CONVOLUTION BLOCK ############
        # 3 sequential conv2D layers: (1,40,282) --> (16, 20, 141) -> (32, 5, 35) -> (64, 1, 8)
        self.conv2Dblock2 = nn.Sequential(
            
            # 1st 2D convolution layer
            nn.Conv2d(
                in_channels=1, # input volume depth == input channel dim == 1
                out_channels=16, # expand output feature map volume's depth to 16
                kernel_size=3, # typical 3*3 stride 1 kernel
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(16), # batch normalize the output feature map before activation
            nn.ReLU(), # feature map --> activation map
            nn.MaxPool2d(kernel_size=2, stride=2), #typical maxpool kernel size
            nn.Dropout(p=0.3), #randomly zero 30% of 1st layer's output feature map in training
             nn.Conv2d(
                in_channels=16, 
                out_channels=32, # expand output feature map volume's depth to 32
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4), # increase maxpool kernel for subsequent filters
            nn.Dropout(p=0.3), 
            
            # 3rd 2D convolution layer identical to last except output dim
            nn.Conv2d(
                in_channels=32,
                out_channels=64, # expand output feature map volume's depth to 64
                kernel_size=3,
                stride=1,
                padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
        )
        self.fc1_linear = nn.Linear(512*2+40,num_emotions) 
        
        ### Softmax layer for the 8 output logits from final FC linear layer 
        self.softmax_out = nn.Softmax(dim=1) # dim==1 is the freq embedding
    def forward(self,x):
        
        ############ 1st parallel Conv2D block: 4 Convolutional layers ############################
        # create final feature embedding from 1st convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding1 = self.conv2Dblock1(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding1 = torch.flatten(conv2d_embedding1, start_dim=1) 
        
        ############ 2nd parallel Conv2D block: 4 Convolutional layers #############################
        # create final feature embedding from 2nd convolutional layer 
        # input features pased through 4 sequential 2D convolutional layers
        conv2d_embedding2 = self.conv2Dblock2(x) # x == N/batch * channel * freq * time
        
        # flatten final 64*1*8 feature map from convolutional layers to length 512 1D array 
        # skip the 1st (N/batch) dimension when flattening
        conv2d_embedding2 = torch.flatten(conv2d_embedding2, start_dim=1) 
        
         
        ########## 4-encoder-layer Transformer block w/ 40-->512-->40 feedfwd network ##############
        # maxpool input feature map: 1*40*282 w/ 1*4 kernel --> 1*40*70
        x_maxpool = self.transformer_maxpool(x)

        # remove channel dim: 1*40*70 --> 40*70
        x_maxpool_reduced = torch.squeeze(x_maxpool,1)
        
        # convert maxpooled feature map format: batch * freq * time ---> time * batch * freq format
        # because transformer encoder layer requires tensor in format: time * batch * embedding (freq)
        x = x_maxpool_reduced.permute(2,0,1) 
        
        # finally, pass reduced input feature map x into transformer encoder layers
        transformer_output = self.transformer_encoder(x)
        
        # create final feature emedding from transformer layer by taking mean in the time dimension (now the 0th dim)
        # transformer outputs 2x40 (MFCC embedding*time) feature map, take mean of columns i.e. take time average
        transformer_embedding = torch.mean(transformer_output, dim=0) # dim 40x70 --> 40
        complete_embedding = torch.cat([conv2d_embedding1, conv2d_embedding2,transformer_embedding], dim=1)  

        ######### final FC linear layer, need logits for loss #########################
        output_logits = self.fc1_linear(complete_embedding)  
        
        ######### Final Softmax layer: use logits from FC linear, get softmax for prediction ######
        output_softmax = self.softmax_out(output_logits)
        
        # need output logits to compute cross entropy loss, need softmax probabilities to predict class
        return output_logits, output_softmax

# %%
# !pip install torchinfo
from torchinfo import summary

# need device to instantiate model
device = 'cpu'

# instantiate model for 8 emotions and move to GPU 
model = parallel_all_you_want(len(emotions_dict)).to(device)

# include input feature map dims in call to summary()
summary(model, input_size=(2,1,40,282))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.2
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# parallel_all_you_want                         [2, 8]                    --
# ├─Sequential: 1-1                             [2, 64, 1, 8]             --
# │    └─Conv2d: 2-1                            [2, 16, 40, 282]          160
# │    └─BatchNorm2d: 2-2                       [2, 16, 40, 282]          32
# │    └─ReLU: 2-3                              [2, 16, 40, 282]          --
# │    └─MaxPool2d: 2-4                         [2, 16, 20, 141]          --
# │    └─Dropout: 2-5                           [2, 16, 20, 141]          --
# │    └─Conv2d: 2-6                            [2, 32, 20, 141]          4,640
# │    └─BatchNorm2d: 2-7                       [2, 32, 20, 141]          64
# │    └─ReLU: 2-8                              [2, 32, 20, 141]          --
# │    └─MaxPool2d: 2-9                         [2, 32, 5, 35]            --
# │    └─Dropout: 2-10                          [2, 32, 5, 35]            --
# │    └─Conv2d: 2-11                           [2, 64, 5, 35]            18,496
# │    └─BatchNorm2d: 2-12                      [2, 64, 5, 35]            128
# │    └─ReLU: 2-13                             [2, 64, 5, 35]            --
# │    └─MaxPool2d: 2-14                        [2, 64, 1, 8]             --
# │    └─Dropout: 2-15                          [2, 64, 1, 8]             --
# ├─Sequential: 1-2                             [2, 64, 1, 8]             --
# │    └─Conv2d: 2-16                           [2, 16, 40, 282]          160
# │    └─BatchNorm2d: 2-17                      [2, 16, 40, 282]          32
# │    └─ReLU: 2-18                             [2, 16, 40, 282]          --
# │    └─MaxPool2d: 2-19                        [2, 16, 20, 141]          --
# │    └─Dropout: 2-20                          [2, 16, 20, 141]          --
# │    └─Conv2d: 2-21                           [2, 32, 20, 141]          4,640
# │    └─BatchNorm2d: 2-22                      [2, 32, 20, 141]          64
# │    └─ReLU: 2-23                             [2, 32, 20, 141]          --
# │    └─MaxPool2d: 2-24                        [2, 32, 5, 35]            --
# │    └─Dropout: 2-25                          [2, 32, 5, 35]            --
# │    └─Conv2d: 2-26                           [2, 64, 5, 35]            18,496
# │    └─BatchNorm2d: 2-27                      [2, 64, 5, 35]            128
# │    └─ReLU: 2-28                             [2, 64, 5, 35]            --
# │    └─MaxPool2d: 2-29                        [2, 64, 1, 8]             --
# │    └─Dropout: 2-30                          [2, 64, 1, 8]             --
# ├─MaxPool2d: 1-3                              [2, 1, 40, 70]            --
# ├─TransformerEncoder: 1-4                     [70, 2, 40]               --
# │    └─ModuleList: 2-31                       --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [70, 2, 40]               48,232
# │    │    └─TransformerEncoderLayer: 3-2      [70, 2, 40]               48,232
# │    │    └─TransformerEncoderLayer: 3-3      [70, 2, 40]               48,232
# │    │    └─TransformerEncoderLayer: 3-4      [70, 2, 40]               48,232
# ├─Linear: 1-5                                 [2, 8]                    8,520
# ├─Softmax: 1-6                                [2, 8]                    --
# ===============================================================================================
# Total params: 248,488
# Trainable params: 248,488
# Non-trainable params: 0
# Total mult-adds (M): 84.19
# ===============================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 20.87
# Params size (MB): 0.89
# Estimated Total Size (MB): 21.85
# ===============================================================================================

# %%
def criterion(predictions, targets): 
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# %%
# define function to create a single step of the training phase
def make_train_step(model, criterion, optimizer):
    
    # define the training step of the training phase
    def train_step(X,Y):
        
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y) 
        
        # compute gradients for the optimizer to use 
        loss.backward()
        
        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()
        
        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad() 
        
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,criterion):
    def validate(X,Y):
        
        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase: 
        with torch.no_grad(): 
            
            # set model to validation phase i.e. turn off dropout and batchnorm layers 
            model.eval()
      
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            print(predictions.shape, "pred_shape")
            print(Y.shape, "Y_shape")

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            
            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits,Y)
            
        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint(): 
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint

def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
# get training set size to calculate # iterations and minibatch indices
train_size = X_train.shape[0]

# pick minibatch size (of 32... always)
minibatch = 32

# set device to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'{device} selected')

# instantiate model and move to GPU for training
model = parallel_all_you_want(num_emotions=len(emotions_dict)).to(device) 
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )

# encountered bugs in google colab only, unless I explicitly defined optimizer in this cell...
optimizer = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

# instantiate the checkpoint save function
save_checkpoint = make_save_checkpoint()

# instantiate the training step function 
train_step = make_train_step(model, criterion, optimizer=optimizer)

# instantiate the validation loop function
validate = make_validate_fnc(model,criterion)

# instantiate lists to hold scalar performance metrics to plot later
train_losses=[]
valid_losses = []

# create training loop for one complete epoch (entire training set)
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):

    for epoch in range(num_epochs):
        
        # set model to train phase
        model.train()         
        
        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size) 
        
        # shuffle the training set for each epoch:
        X_train = X_train[train_indices,:,:,:] 
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate 
        epoch_acc = 0 
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)
        
        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):
            
            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch 
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size) 
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start 
            
            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:] 
            # get training minibatch labels 
            Y = Y_train[batch_start:batch_end] 

            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float() 
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor,Y_tensor) 
            
            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size
            
            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch+1}: iteration {i}/{num_iterations}',end='')
        
        # create tensors from validation set
        X_valid_tensor = torch.tensor(X_valid,device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        print(X_valid_tensor.shape)
        print(Y_valid_tensor.shape)
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor,Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
                  
        # Save checkpoint of the model
        checkpoint_filename = './drive/MyDrive/content/checkpoints/parallel_all_you_wantFINAL-{:03d}.pkl'.format(epoch)
        save_checkpoint(optimizer, model, epoch, checkpoint_filename)
        
        # keep track of each epoch's progress
        print(f'\nEpoch {epoch+1} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')
# Out:
# cpu selected
# Number of trainable params:  248488

# %%
# choose number of epochs higher than reasonable so we can manually stop training 
num_epochs = 500

# train it!
train(optimizer, model, num_epochs, X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 1: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 1 --- loss:4.237, Epoch accuracy:21.27%, Validation loss:1.943, Validation accuracy:30.77%
# Epoch 2: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 2 --- loss:1.910, Epoch accuracy:31.65%, Validation loss:2.124, Validation accuracy:26.57%
# Epoch 3: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 3 --- loss:1.766, Epoch accuracy:34.26%, Validation loss:1.803, Validation accuracy:36.36%
# Epoch 4: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 4 --- loss:1.643, Epoch accuracy:37.49%, Validation loss:1.933, Validation accuracy:38.46%
# Epoch 5: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 5 --- loss:1.536, Epoch accuracy:42.20%, Validation loss:1.591, Validation accuracy:40.56%
# Epoch 6: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 6 --- loss:1.447, Epoch accuracy:42.98%, Validation loss:1.767, Validation accuracy:38.46%
# Epoch 7: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 7 --- loss:1.400, Epoch accuracy:45.42%, Validation loss:1.583, Validation accuracy:41.26%
# Epoch 8: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 8 --- loss:1.348, Epoch accuracy:47.34%, Validation loss:1.396, Validation accuracy:44.76%
# Epoch 9: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 9 --- loss:1.260, Epoch accuracy:50.83%, Validation loss:1.420, Validation accuracy:45.45%
# Epoch 10: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 10 --- loss:1.262, Epoch accuracy:50.13%, Validation loss:1.478, Validation accuracy:51.05%
# Epoch 11: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 11 --- loss:1.267, Epoch accuracy:50.83%, Validation loss:1.361, Validation accuracy:51.75%
# Epoch 12: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 12 --- loss:1.170, Epoch accuracy:53.88%, Validation loss:1.379, Validation accuracy:49.65%
# Epoch 13: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 13 --- loss:1.200, Epoch accuracy:55.62%, Validation loss:1.437, Validation accuracy:50.35%
# Epoch 14: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 14 --- loss:1.197, Epoch accuracy:54.40%, Validation loss:1.366, Validation accuracy:51.75%
# Epoch 15: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 15 --- loss:1.148, Epoch accuracy:56.58%, Validation loss:1.424, Validation accuracy:47.55%
# Epoch 16: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 16 --- loss:1.118, Epoch accuracy:56.76%, Validation loss:1.419, Validation accuracy:47.55%
# Epoch 17: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 17 --- loss:1.072, Epoch accuracy:57.37%, Validation loss:1.529, Validation accuracy:46.85%
# Epoch 18: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 18 --- loss:1.066, Epoch accuracy:59.46%, Validation loss:1.613, Validation accuracy:42.66%
# Epoch 19: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 19 --- loss:1.041, Epoch accuracy:61.73%, Validation loss:1.305, Validation accuracy:54.55%
# Epoch 20: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 20 --- loss:1.055, Epoch accuracy:57.89%, Validation loss:1.309, Validation accuracy:53.85%
# Epoch 21: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 21 --- loss:1.004, Epoch accuracy:61.81%, Validation loss:1.215, Validation accuracy:55.24%
# Epoch 22: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 22 --- loss:0.990, Epoch accuracy:60.42%, Validation loss:1.312, Validation accuracy:52.45%
# Epoch 23: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 23 --- loss:0.936, Epoch accuracy:63.91%, Validation loss:1.260, Validation accuracy:56.64%
# Epoch 24: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 24 --- loss:0.940, Epoch accuracy:63.99%, Validation loss:1.269, Validation accuracy:52.45%
# Epoch 25: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 25 --- loss:0.949, Epoch accuracy:63.99%, Validation loss:1.298, Validation accuracy:52.45%
# Epoch 26: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 26 --- loss:0.877, Epoch accuracy:65.91%, Validation loss:1.164, Validation accuracy:57.34%
# Epoch 27: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 27 --- loss:0.867, Epoch accuracy:64.86%, Validation loss:1.285, Validation accuracy:55.94%
# Epoch 28: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 28 --- loss:0.830, Epoch accuracy:67.57%, Validation loss:1.145, Validation accuracy:60.84%
# Epoch 29: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 29 --- loss:0.802, Epoch accuracy:67.92%, Validation loss:1.192, Validation accuracy:59.44%
# Epoch 30: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 30 --- loss:0.819, Epoch accuracy:67.74%, Validation loss:1.306, Validation accuracy:55.94%
# Epoch 31: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 31 --- loss:0.818, Epoch accuracy:66.70%, Validation loss:1.221, Validation accuracy:58.74%
# Epoch 32: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 32 --- loss:0.789, Epoch accuracy:67.83%, Validation loss:1.142, Validation accuracy:60.14%
# Epoch 33: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 33 --- loss:0.734, Epoch accuracy:70.71%, Validation loss:1.181, Validation accuracy:61.54%
# Epoch 34: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 34 --- loss:0.769, Epoch accuracy:68.35%, Validation loss:1.198, Validation accuracy:55.94%
# Epoch 35: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 35 --- loss:0.742, Epoch accuracy:69.66%, Validation loss:1.255, Validation accuracy:61.54%
# Epoch 36: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 36 --- loss:0.704, Epoch accuracy:71.75%, Validation loss:1.128, Validation accuracy:59.44%
# Epoch 37: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 37 --- loss:0.683, Epoch accuracy:72.19%, Validation loss:1.213, Validation accuracy:60.84%
# Epoch 38: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 38 --- loss:0.758, Epoch accuracy:69.66%, Validation loss:1.272, Validation accuracy:58.74%
# Epoch 39: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 39 --- loss:0.644, Epoch accuracy:74.19%, Validation loss:1.178, Validation accuracy:64.34%
# Epoch 40: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 40 --- loss:0.689, Epoch accuracy:72.01%, Validation loss:1.206, Validation accuracy:56.64%
# Epoch 41: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 41 --- loss:0.607, Epoch accuracy:75.68%, Validation loss:1.133, Validation accuracy:62.24%
# Epoch 42: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 42 --- loss:0.602, Epoch accuracy:75.07%, Validation loss:1.141, Validation accuracy:66.43%
# Epoch 43: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 43 --- loss:0.651, Epoch accuracy:74.80%, Validation loss:1.195, Validation accuracy:61.54%
# Epoch 44: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 44 --- loss:0.601, Epoch accuracy:75.85%, Validation loss:1.180, Validation accuracy:62.94%
# Epoch 45: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 45 --- loss:0.569, Epoch accuracy:75.94%, Validation loss:1.274, Validation accuracy:58.04%
# Epoch 46: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 46 --- loss:0.556, Epoch accuracy:78.81%, Validation loss:1.233, Validation accuracy:61.54%
# Epoch 47: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 47 --- loss:0.537, Epoch accuracy:77.94%, Validation loss:1.309, Validation accuracy:58.04%
# Epoch 48: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 48 --- loss:0.573, Epoch accuracy:76.11%, Validation loss:1.164, Validation accuracy:57.34%
# Epoch 49: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 49 --- loss:0.590, Epoch accuracy:75.59%, Validation loss:1.329, Validation accuracy:60.84%
# Epoch 50: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 50 --- loss:0.511, Epoch accuracy:79.34%, Validation loss:1.246, Validation accuracy:57.34%
# Epoch 51: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 51 --- loss:0.497, Epoch accuracy:79.08%, Validation loss:1.328, Validation accuracy:60.84%
# Epoch 52: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 52 --- loss:0.531, Epoch accuracy:77.68%, Validation loss:1.321, Validation accuracy:60.84%
# Epoch 53: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 53 --- loss:0.496, Epoch accuracy:79.86%, Validation loss:1.188, Validation accuracy:61.54%
# Epoch 54: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 54 --- loss:0.456, Epoch accuracy:80.30%, Validation loss:1.204, Validation accuracy:62.24%
# Epoch 55: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 55 --- loss:0.461, Epoch accuracy:81.69%, Validation loss:1.270, Validation accuracy:62.94%
# Epoch 56: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 56 --- loss:0.447, Epoch accuracy:80.56%, Validation loss:1.180, Validation accuracy:69.23%
# Epoch 57: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 57 --- loss:0.429, Epoch accuracy:81.34%, Validation loss:1.179, Validation accuracy:66.43%
# Epoch 58: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 58 --- loss:0.475, Epoch accuracy:79.51%, Validation loss:1.206, Validation accuracy:61.54%
# Epoch 59: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 59 --- loss:0.442, Epoch accuracy:81.60%, Validation loss:1.213, Validation accuracy:65.73%
# Epoch 60: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 60 --- loss:0.459, Epoch accuracy:81.17%, Validation loss:1.093, Validation accuracy:69.23%
# Epoch 61: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 61 --- loss:0.399, Epoch accuracy:83.61%, Validation loss:1.186, Validation accuracy:58.04%
# Epoch 62: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 62 --- loss:0.389, Epoch accuracy:84.13%, Validation loss:1.140, Validation accuracy:64.34%
# Epoch 63: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 63 --- loss:0.398, Epoch accuracy:84.31%, Validation loss:1.200, Validation accuracy:62.24%
# Epoch 64: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 64 --- loss:0.390, Epoch accuracy:83.96%, Validation loss:1.296, Validation accuracy:55.24%
# Epoch 65: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 65 --- loss:0.351, Epoch accuracy:85.27%, Validation loss:1.156, Validation accuracy:60.14%
# Epoch 66: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 66 --- loss:0.398, Epoch accuracy:82.39%, Validation loss:1.097, Validation accuracy:69.23%
# Epoch 67: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 67 --- loss:0.353, Epoch accuracy:84.83%, Validation loss:1.294, Validation accuracy:62.24%
# Epoch 68: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 68 --- loss:0.341, Epoch accuracy:86.57%, Validation loss:1.285, Validation accuracy:62.94%
# Epoch 69: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 69 --- loss:0.289, Epoch accuracy:88.14%, Validation loss:1.248, Validation accuracy:62.94%
# Epoch 70: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 70 --- loss:0.298, Epoch accuracy:87.01%, Validation loss:1.063, Validation accuracy:66.43%
# Epoch 71: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 71 --- loss:0.336, Epoch accuracy:85.35%, Validation loss:1.186, Validation accuracy:66.43%
# Epoch 72: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 72 --- loss:0.347, Epoch accuracy:84.57%, Validation loss:1.287, Validation accuracy:64.34%
# Epoch 73: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 73 --- loss:0.310, Epoch accuracy:86.31%, Validation loss:1.260, Validation accuracy:64.34%
# Epoch 74: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 74 --- loss:0.272, Epoch accuracy:89.10%, Validation loss:1.415, Validation accuracy:58.74%
# Epoch 75: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 75 --- loss:0.279, Epoch accuracy:88.06%, Validation loss:1.272, Validation accuracy:62.94%
# Epoch 76: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 76 --- loss:0.277, Epoch accuracy:88.32%, Validation loss:1.349, Validation accuracy:65.73%
# Epoch 77: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 77 --- loss:0.272, Epoch accuracy:88.58%, Validation loss:1.245, Validation accuracy:60.84%
# Epoch 78: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 78 --- loss:0.278, Epoch accuracy:88.23%, Validation loss:1.179, Validation accuracy:67.13%
# Epoch 79: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 79 --- loss:0.262, Epoch accuracy:89.19%, Validation loss:1.254, Validation accuracy:64.34%
# Epoch 80: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 80 --- loss:0.257, Epoch accuracy:88.93%, Validation loss:1.170, Validation accuracy:68.53%
# Epoch 81: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 81 --- loss:0.239, Epoch accuracy:89.36%, Validation loss:1.223, Validation accuracy:67.13%
# Epoch 82: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 82 --- loss:0.244, Epoch accuracy:89.45%, Validation loss:1.231, Validation accuracy:67.13%
# Epoch 83: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 83 --- loss:0.239, Epoch accuracy:89.45%, Validation loss:1.601, Validation accuracy:55.94%
# Epoch 84: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 84 --- loss:0.233, Epoch accuracy:89.80%, Validation loss:1.436, Validation accuracy:60.84%
# Epoch 85: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 85 --- loss:0.253, Epoch accuracy:89.45%, Validation loss:1.399, Validation accuracy:59.44%
# Epoch 86: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 86 --- loss:0.235, Epoch accuracy:89.97%, Validation loss:1.391, Validation accuracy:62.24%
# Epoch 87: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 87 --- loss:0.213, Epoch accuracy:90.24%, Validation loss:1.415, Validation accuracy:59.44%
# Epoch 88: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 88 --- loss:0.227, Epoch accuracy:89.45%, Validation loss:1.382, Validation accuracy:60.84%
# Epoch 89: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 89 --- loss:0.251, Epoch accuracy:89.28%, Validation loss:1.260, Validation accuracy:66.43%
# Epoch 90: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 90 --- loss:0.233, Epoch accuracy:90.06%, Validation loss:1.417, Validation accuracy:65.73%
# Epoch 91: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 91 --- loss:0.212, Epoch accuracy:89.71%, Validation loss:1.400, Validation accuracy:60.14%
# Epoch 92: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 92 --- loss:0.228, Epoch accuracy:89.10%, Validation loss:1.410, Validation accuracy:62.24%
# Epoch 93: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 93 --- loss:0.204, Epoch accuracy:90.93%, Validation loss:1.505, Validation accuracy:60.84%
# Epoch 94: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 94 --- loss:0.204, Epoch accuracy:90.67%, Validation loss:1.493, Validation accuracy:61.54%
# Epoch 95: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 95 --- loss:0.175, Epoch accuracy:91.80%, Validation loss:1.442, Validation accuracy:63.64%
# Epoch 96: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 96 --- loss:0.167, Epoch accuracy:92.24%, Validation loss:1.474, Validation accuracy:61.54%
# Epoch 97: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 97 --- loss:0.159, Epoch accuracy:93.11%, Validation loss:1.570, Validation accuracy:65.03%
# Epoch 98: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 98 --- loss:0.183, Epoch accuracy:91.19%, Validation loss:1.424, Validation accuracy:60.84%
# Epoch 99: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 99 --- loss:0.178, Epoch accuracy:91.37%, Validation loss:1.481, Validation accuracy:61.54%
# Epoch 100: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 100 --- loss:0.167, Epoch accuracy:92.33%, Validation loss:1.425, Validation accuracy:63.64%
# Epoch 101: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 101 --- loss:0.137, Epoch accuracy:93.72%, Validation loss:1.431, Validation accuracy:61.54%
# Epoch 102: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 102 --- loss:0.173, Epoch accuracy:91.19%, Validation loss:1.538, Validation accuracy:59.44%
# Epoch 103: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 103 --- loss:0.168, Epoch accuracy:92.15%, Validation loss:1.519, Validation accuracy:62.24%
# Epoch 104: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 104 --- loss:0.157, Epoch accuracy:92.76%, Validation loss:1.453, Validation accuracy:60.84%
# Epoch 105: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 105 --- loss:0.124, Epoch accuracy:94.33%, Validation loss:1.370, Validation accuracy:60.84%
# Epoch 106: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 106 --- loss:0.138, Epoch accuracy:93.98%, Validation loss:1.474, Validation accuracy:62.24%
# Epoch 107: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 107 --- loss:0.135, Epoch accuracy:93.11%, Validation loss:1.475, Validation accuracy:58.04%
# Epoch 108: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 108 --- loss:0.169, Epoch accuracy:91.89%, Validation loss:1.679, Validation accuracy:63.64%
# Epoch 109: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 109 --- loss:0.153, Epoch accuracy:92.24%, Validation loss:1.585, Validation accuracy:62.94%
# Epoch 110: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 110 --- loss:0.131, Epoch accuracy:93.81%, Validation loss:1.545, Validation accuracy:61.54%
# Epoch 111: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 111 --- loss:0.108, Epoch accuracy:94.59%, Validation loss:1.362, Validation accuracy:66.43%
# Epoch 112: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 112 --- loss:0.138, Epoch accuracy:92.94%, Validation loss:1.531, Validation accuracy:64.34%
# Epoch 113: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 113 --- loss:0.153, Epoch accuracy:92.33%, Validation loss:1.315, Validation accuracy:67.13%
# Epoch 114: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 114 --- loss:0.134, Epoch accuracy:93.81%, Validation loss:1.724, Validation accuracy:58.04%
# Epoch 115: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 115 --- loss:0.131, Epoch accuracy:93.37%, Validation loss:1.474, Validation accuracy:61.54%
# Epoch 116: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 116 --- loss:0.148, Epoch accuracy:93.72%, Validation loss:1.612, Validation accuracy:59.44%
# Epoch 117: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 117 --- loss:0.147, Epoch accuracy:93.29%, Validation loss:1.515, Validation accuracy:61.54%
# Epoch 118: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 118 --- loss:0.128, Epoch accuracy:93.55%, Validation loss:1.519, Validation accuracy:59.44%
# Epoch 119: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 119 --- loss:0.127, Epoch accuracy:93.37%, Validation loss:1.378, Validation accuracy:63.64%
# Epoch 120: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 120 --- loss:0.126, Epoch accuracy:94.25%, Validation loss:1.465, Validation accuracy:62.94%
# Epoch 121: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 121 --- loss:0.108, Epoch accuracy:94.42%, Validation loss:1.693, Validation accuracy:59.44%
# Epoch 122: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 122 --- loss:0.085, Epoch accuracy:95.47%, Validation loss:1.441, Validation accuracy:66.43%
# Epoch 123: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 123 --- loss:0.085, Epoch accuracy:95.64%, Validation loss:1.474, Validation accuracy:64.34%
# Epoch 124: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 124 --- loss:0.160, Epoch accuracy:92.76%, Validation loss:1.531, Validation accuracy:63.64%
# Epoch 125: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 125 --- loss:0.124, Epoch accuracy:94.07%, Validation loss:1.592, Validation accuracy:64.34%
# Epoch 126: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 126 --- loss:0.123, Epoch accuracy:93.37%, Validation loss:1.592, Validation accuracy:59.44%
# Epoch 127: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 127 --- loss:0.115, Epoch accuracy:94.25%, Validation loss:1.538, Validation accuracy:61.54%
# Epoch 128: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 128 --- loss:0.109, Epoch accuracy:94.33%, Validation loss:1.576, Validation accuracy:64.34%
# Epoch 129: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 129 --- loss:0.097, Epoch accuracy:95.12%, Validation loss:1.405, Validation accuracy:62.24%
# Epoch 130: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 130 --- loss:0.090, Epoch accuracy:94.68%, Validation loss:1.440, Validation accuracy:62.24%
# Epoch 131: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 131 --- loss:0.104, Epoch accuracy:94.59%, Validation loss:1.558, Validation accuracy:62.94%
# Epoch 132: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 132 --- loss:0.108, Epoch accuracy:94.86%, Validation loss:1.475, Validation accuracy:60.84%
# Epoch 133: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 133 --- loss:0.124, Epoch accuracy:93.20%, Validation loss:1.678, Validation accuracy:59.44%
# Epoch 134: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 134 --- loss:0.101, Epoch accuracy:94.33%, Validation loss:1.639, Validation accuracy:56.64%
# Epoch 135: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 135 --- loss:0.081, Epoch accuracy:95.55%, Validation loss:1.658, Validation accuracy:62.24%
# Epoch 136: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 136 --- loss:0.074, Epoch accuracy:95.90%, Validation loss:1.669, Validation accuracy:60.84%
# Epoch 137: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 137 --- loss:0.075, Epoch accuracy:95.64%, Validation loss:1.552, Validation accuracy:62.24%
# Epoch 138: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 138 --- loss:0.058, Epoch accuracy:96.77%, Validation loss:1.506, Validation accuracy:64.34%
# Epoch 139: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 139 --- loss:0.076, Epoch accuracy:95.55%, Validation loss:1.716, Validation accuracy:62.24%
# Epoch 140: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 140 --- loss:0.073, Epoch accuracy:95.73%, Validation loss:1.591, Validation accuracy:63.64%
# Epoch 141: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 141 --- loss:0.065, Epoch accuracy:96.08%, Validation loss:1.689, Validation accuracy:64.34%
# Epoch 142: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 142 --- loss:0.058, Epoch accuracy:96.69%, Validation loss:1.701, Validation accuracy:59.44%
# Epoch 143: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 143 --- loss:0.073, Epoch accuracy:95.64%, Validation loss:1.720, Validation accuracy:62.94%
# Epoch 144: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 144 --- loss:0.071, Epoch accuracy:95.82%, Validation loss:1.917, Validation accuracy:59.44%
# Epoch 145: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 145 --- loss:0.093, Epoch accuracy:94.77%, Validation loss:1.945, Validation accuracy:57.34%
# Epoch 146: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 146 --- loss:0.082, Epoch accuracy:95.03%, Validation loss:1.914, Validation accuracy:62.94%
# Epoch 147: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 147 --- loss:0.073, Epoch accuracy:95.47%, Validation loss:1.633, Validation accuracy:66.43%
# Epoch 148: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 148 --- loss:0.078, Epoch accuracy:95.73%, Validation loss:1.494, Validation accuracy:63.64%
# Epoch 149: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 149 --- loss:0.099, Epoch accuracy:94.16%, Validation loss:1.753, Validation accuracy:59.44%
# Epoch 150: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 150 --- loss:0.068, Epoch accuracy:95.82%, Validation loss:1.801, Validation accuracy:62.94%
# Epoch 151: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 151 --- loss:0.055, Epoch accuracy:96.60%, Validation loss:1.621, Validation accuracy:62.24%
# Epoch 152: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 152 --- loss:0.044, Epoch accuracy:96.86%, Validation loss:1.672, Validation accuracy:63.64%
# Epoch 153: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 153 --- loss:0.061, Epoch accuracy:96.34%, Validation loss:1.639, Validation accuracy:63.64%
# Epoch 154: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 154 --- loss:0.056, Epoch accuracy:96.25%, Validation loss:1.577, Validation accuracy:66.43%
# Epoch 155: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 155 --- loss:0.061, Epoch accuracy:95.90%, Validation loss:1.661, Validation accuracy:61.54%
# Epoch 156: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 156 --- loss:0.047, Epoch accuracy:96.86%, Validation loss:1.883, Validation accuracy:58.04%
# Epoch 157: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 157 --- loss:0.060, Epoch accuracy:96.51%, Validation loss:1.754, Validation accuracy:61.54%
# Epoch 158: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 158 --- loss:0.082, Epoch accuracy:95.20%, Validation loss:1.732, Validation accuracy:64.34%
# Epoch 159: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 159 --- loss:0.066, Epoch accuracy:95.73%, Validation loss:1.737, Validation accuracy:61.54%
# Epoch 160: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 160 --- loss:0.061, Epoch accuracy:96.25%, Validation loss:1.763, Validation accuracy:62.94%
# Epoch 161: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 161 --- loss:0.075, Epoch accuracy:95.73%, Validation loss:1.863, Validation accuracy:61.54%
# Epoch 162: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 162 --- loss:0.051, Epoch accuracy:96.51%, Validation loss:1.697, Validation accuracy:65.03%
# Epoch 163: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 163 --- loss:0.050, Epoch accuracy:96.25%, Validation loss:1.652, Validation accuracy:65.73%
# Epoch 164: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 164 --- loss:0.129, Epoch accuracy:93.46%, Validation loss:1.798, Validation accuracy:60.84%
# Epoch 165: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 165 --- loss:0.061, Epoch accuracy:96.25%, Validation loss:1.769, Validation accuracy:58.74%
# Epoch 166: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 166 --- loss:0.084, Epoch accuracy:94.94%, Validation loss:1.728, Validation accuracy:62.24%
# Epoch 167: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 167 --- loss:0.048, Epoch accuracy:96.51%, Validation loss:1.642, Validation accuracy:60.84%
# Epoch 168: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 168 --- loss:0.059, Epoch accuracy:95.64%, Validation loss:1.585, Validation accuracy:67.83%
# Epoch 169: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 169 --- loss:0.052, Epoch accuracy:96.86%, Validation loss:1.574, Validation accuracy:65.03%
# Epoch 170: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 170 --- loss:0.051, Epoch accuracy:96.43%, Validation loss:1.603, Validation accuracy:63.64%
# Epoch 171: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 171 --- loss:0.064, Epoch accuracy:95.73%, Validation loss:1.822, Validation accuracy:57.34%
# Epoch 172: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 172 --- loss:0.073, Epoch accuracy:95.20%, Validation loss:1.664, Validation accuracy:62.94%
# Epoch 173: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 173 --- loss:0.056, Epoch accuracy:96.25%, Validation loss:1.824, Validation accuracy:61.54%
# Epoch 174: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 174 --- loss:0.084, Epoch accuracy:95.38%, Validation loss:1.692, Validation accuracy:62.94%
# Epoch 175: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 175 --- loss:0.034, Epoch accuracy:97.30%, Validation loss:1.713, Validation accuracy:63.64%
# Epoch 176: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 176 --- loss:0.034, Epoch accuracy:97.12%, Validation loss:1.663, Validation accuracy:61.54%
# Epoch 177: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 177 --- loss:0.038, Epoch accuracy:97.04%, Validation loss:1.746, Validation accuracy:64.34%
# Epoch 178: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 178 --- loss:0.042, Epoch accuracy:96.51%, Validation loss:1.712, Validation accuracy:65.73%
# Epoch 179: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 179 --- loss:0.037, Epoch accuracy:97.12%, Validation loss:1.782, Validation accuracy:62.24%
# Epoch 180: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 180 --- loss:0.032, Epoch accuracy:97.21%, Validation loss:1.704, Validation accuracy:65.03%
# Epoch 181: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 181 --- loss:0.032, Epoch accuracy:97.12%, Validation loss:1.739, Validation accuracy:61.54%
# Epoch 182: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 182 --- loss:0.030, Epoch accuracy:97.38%, Validation loss:1.826, Validation accuracy:60.84%
# Epoch 183: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 183 --- loss:0.036, Epoch accuracy:96.77%, Validation loss:1.914, Validation accuracy:61.54%
# Epoch 184: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 184 --- loss:0.052, Epoch accuracy:96.43%, Validation loss:1.748, Validation accuracy:67.13%
# Epoch 185: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 185 --- loss:0.054, Epoch accuracy:96.51%, Validation loss:1.713, Validation accuracy:65.03%
# Epoch 186: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 186 --- loss:0.050, Epoch accuracy:96.34%, Validation loss:1.691, Validation accuracy:63.64%
# Epoch 187: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 187 --- loss:0.053, Epoch accuracy:96.25%, Validation loss:1.785, Validation accuracy:65.03%
# Epoch 188: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 188 --- loss:0.071, Epoch accuracy:95.29%, Validation loss:1.712, Validation accuracy:65.03%
# Epoch 189: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 189 --- loss:0.047, Epoch accuracy:96.69%, Validation loss:1.968, Validation accuracy:62.94%
# Epoch 190: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 190 --- loss:0.055, Epoch accuracy:95.73%, Validation loss:1.865, Validation accuracy:61.54%
# Epoch 191: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 191 --- loss:0.054, Epoch accuracy:96.16%, Validation loss:1.830, Validation accuracy:61.54%
# Epoch 192: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 192 --- loss:0.054, Epoch accuracy:96.51%, Validation loss:1.806, Validation accuracy:62.24%
# Epoch 193: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 193 --- loss:0.039, Epoch accuracy:96.95%, Validation loss:1.962, Validation accuracy:61.54%
# Epoch 194: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 194 --- loss:0.033, Epoch accuracy:97.04%, Validation loss:1.796, Validation accuracy:64.34%
# Epoch 195: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 195 --- loss:0.024, Epoch accuracy:97.56%, Validation loss:1.785, Validation accuracy:62.24%
# Epoch 196: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 196 --- loss:0.033, Epoch accuracy:96.86%, Validation loss:1.729, Validation accuracy:61.54%
# Epoch 197: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 197 --- loss:0.025, Epoch accuracy:97.30%, Validation loss:1.735, Validation accuracy:62.24%
# Epoch 198: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 198 --- loss:0.025, Epoch accuracy:97.47%, Validation loss:1.721, Validation accuracy:62.94%
# Epoch 199: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 199 --- loss:0.048, Epoch accuracy:96.08%, Validation loss:1.813, Validation accuracy:62.24%
# Epoch 200: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 200 --- loss:0.038, Epoch accuracy:97.04%, Validation loss:1.838, Validation accuracy:61.54%
# Epoch 201: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 201 --- loss:0.029, Epoch accuracy:97.12%, Validation loss:1.863, Validation accuracy:58.74%
# Epoch 202: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 202 --- loss:0.032, Epoch accuracy:96.95%, Validation loss:1.918, Validation accuracy:60.84%
# Epoch 203: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 203 --- loss:0.040, Epoch accuracy:96.77%, Validation loss:1.682, Validation accuracy:65.73%
# Epoch 204: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 204 --- loss:0.023, Epoch accuracy:97.47%, Validation loss:1.731, Validation accuracy:62.24%
# Epoch 205: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 205 --- loss:0.023, Epoch accuracy:97.30%, Validation loss:1.808, Validation accuracy:60.84%
# Epoch 206: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 206 --- loss:0.062, Epoch accuracy:95.82%, Validation loss:1.723, Validation accuracy:61.54%
# Epoch 207: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 207 --- loss:0.081, Epoch accuracy:94.68%, Validation loss:1.864, Validation accuracy:62.24%
# Epoch 208: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 208 --- loss:0.036, Epoch accuracy:97.12%, Validation loss:1.702, Validation accuracy:64.34%
# Epoch 209: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 209 --- loss:0.038, Epoch accuracy:96.69%, Validation loss:1.816, Validation accuracy:62.94%
# Epoch 210: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 210 --- loss:0.031, Epoch accuracy:97.21%, Validation loss:1.948, Validation accuracy:59.44%
# Epoch 211: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# ...
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 431 --- loss:0.011, Epoch accuracy:97.65%, Validation loss:1.764, Validation accuracy:67.83%
# Epoch 432: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 432 --- loss:0.019, Epoch accuracy:97.47%, Validation loss:1.980, Validation accuracy:62.24%
# Epoch 433: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 433 --- loss:0.018, Epoch accuracy:97.56%, Validation loss:1.842, Validation accuracy:67.13%
# Epoch 434: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 434 --- loss:0.015, Epoch accuracy:97.56%, Validation loss:1.822, Validation accuracy:65.03%
# Epoch 435: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 435 --- loss:0.016, Epoch accuracy:97.47%, Validation loss:1.793, Validation accuracy:62.24%
# Epoch 436: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 436 --- loss:0.013, Epoch accuracy:97.56%, Validation loss:1.739, Validation accuracy:66.43%
# Epoch 437: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 437 --- loss:0.011, Epoch accuracy:97.65%, Validation loss:1.787, Validation accuracy:60.84%
# Epoch 438: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 438 --- loss:0.020, Epoch accuracy:97.30%, Validation loss:1.862, Validation accuracy:62.24%
# Epoch 439: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 439 --- loss:0.025, Epoch accuracy:97.30%, Validation loss:1.936, Validation accuracy:64.34%
# Epoch 440: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 440 --- loss:0.019, Epoch accuracy:97.21%, Validation loss:1.692, Validation accuracy:64.34%
# Epoch 441: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 441 --- loss:0.020, Epoch accuracy:97.38%, Validation loss:1.772, Validation accuracy:66.43%
# Epoch 442: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 442 --- loss:0.016, Epoch accuracy:97.47%, Validation loss:1.820, Validation accuracy:65.03%
# Epoch 443: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 443 --- loss:0.011, Epoch accuracy:97.65%, Validation loss:1.783, Validation accuracy:62.94%
# Epoch 444: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 444 --- loss:0.012, Epoch accuracy:97.47%, Validation loss:1.740, Validation accuracy:63.64%
# Epoch 445: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 445 --- loss:0.012, Epoch accuracy:97.56%, Validation loss:1.798, Validation accuracy:63.64%
# Epoch 446: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 446 --- loss:0.010, Epoch accuracy:97.56%, Validation loss:1.708, Validation accuracy:67.13%
# Epoch 447: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 447 --- loss:0.012, Epoch accuracy:97.65%, Validation loss:1.693, Validation accuracy:65.73%
# Epoch 448: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 448 --- loss:0.016, Epoch accuracy:97.47%, Validation loss:1.701, Validation accuracy:61.54%
# Epoch 449: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 449 --- loss:0.019, Epoch accuracy:97.38%, Validation loss:1.705, Validation accuracy:65.03%
# Epoch 450: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 450 --- loss:0.011, Epoch accuracy:97.56%, Validation loss:1.764, Validation accuracy:67.83%
# Epoch 451: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 451 --- loss:0.021, Epoch accuracy:97.38%, Validation loss:1.797, Validation accuracy:67.13%
# Epoch 452: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 452 --- loss:0.018, Epoch accuracy:97.30%, Validation loss:1.939, Validation accuracy:62.94%
# Epoch 453: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 453 --- loss:0.014, Epoch accuracy:97.65%, Validation loss:1.808, Validation accuracy:63.64%
# Epoch 454: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 454 --- loss:0.015, Epoch accuracy:97.47%, Validation loss:1.716, Validation accuracy:64.34%
# Epoch 455: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 455 --- loss:0.013, Epoch accuracy:97.56%, Validation loss:1.682, Validation accuracy:66.43%
# Epoch 456: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 456 --- loss:0.014, Epoch accuracy:97.56%, Validation loss:1.740, Validation accuracy:64.34%
# Epoch 457: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 457 --- loss:0.009, Epoch accuracy:97.65%, Validation loss:1.750, Validation accuracy:65.73%
# Epoch 458: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 458 --- loss:0.008, Epoch accuracy:97.65%, Validation loss:1.776, Validation accuracy:65.03%
# Epoch 459: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 459 --- loss:0.014, Epoch accuracy:97.47%, Validation loss:1.937, Validation accuracy:65.73%
# Epoch 460: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 460 --- loss:0.051, Epoch accuracy:96.08%, Validation loss:2.114, Validation accuracy:60.14%
# Epoch 461: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 461 --- loss:0.082, Epoch accuracy:95.29%, Validation loss:1.893, Validation accuracy:60.84%
# Epoch 462: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 462 --- loss:0.038, Epoch accuracy:96.25%, Validation loss:1.883, Validation accuracy:61.54%
# Epoch 463: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 463 --- loss:0.050, Epoch accuracy:96.25%, Validation loss:1.979, Validation accuracy:60.84%
# Epoch 464: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 464 --- loss:0.144, Epoch accuracy:92.24%, Validation loss:1.903, Validation accuracy:59.44%
# Epoch 465: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 465 --- loss:0.105, Epoch accuracy:94.33%, Validation loss:2.120, Validation accuracy:58.04%
# Epoch 466: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 466 --- loss:0.062, Epoch accuracy:96.08%, Validation loss:1.680, Validation accuracy:62.94%
# Epoch 467: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 467 --- loss:0.058, Epoch accuracy:95.99%, Validation loss:1.833, Validation accuracy:64.34%
# Epoch 468: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 468 --- loss:0.090, Epoch accuracy:95.29%, Validation loss:2.025, Validation accuracy:59.44%
# Epoch 469: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 469 --- loss:0.039, Epoch accuracy:96.95%, Validation loss:1.645, Validation accuracy:65.73%
# Epoch 470: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 470 --- loss:0.044, Epoch accuracy:96.77%, Validation loss:1.658, Validation accuracy:62.24%
# Epoch 471: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 471 --- loss:0.027, Epoch accuracy:97.04%, Validation loss:1.768, Validation accuracy:64.34%
# Epoch 472: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 472 --- loss:0.022, Epoch accuracy:97.38%, Validation loss:2.316, Validation accuracy:58.04%
# Epoch 473: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 473 --- loss:0.039, Epoch accuracy:96.69%, Validation loss:1.856, Validation accuracy:64.34%
# Epoch 474: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 474 --- loss:0.038, Epoch accuracy:96.77%, Validation loss:1.720, Validation accuracy:63.64%
# Epoch 475: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 475 --- loss:0.018, Epoch accuracy:97.47%, Validation loss:1.740, Validation accuracy:61.54%
# Epoch 476: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 476 --- loss:0.015, Epoch accuracy:97.47%, Validation loss:1.861, Validation accuracy:62.24%
# Epoch 477: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 477 --- loss:0.011, Epoch accuracy:97.65%, Validation loss:1.782, Validation accuracy:63.64%
# Epoch 478: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 478 --- loss:0.010, Epoch accuracy:97.65%, Validation loss:1.713, Validation accuracy:62.94%
# Epoch 479: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 479 --- loss:0.010, Epoch accuracy:97.65%, Validation loss:1.736, Validation accuracy:63.64%
# Epoch 480: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 480 --- loss:0.015, Epoch accuracy:97.38%, Validation loss:1.747, Validation accuracy:66.43%
# Epoch 481: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 481 --- loss:0.012, Epoch accuracy:97.56%, Validation loss:1.888, Validation accuracy:60.14%
# Epoch 482: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 482 --- loss:0.012, Epoch accuracy:97.65%, Validation loss:1.734, Validation accuracy:62.24%
# Epoch 483: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 483 --- loss:0.009, Epoch accuracy:97.65%, Validation loss:1.735, Validation accuracy:62.94%
# Epoch 484: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 484 --- loss:0.011, Epoch accuracy:97.65%, Validation loss:1.767, Validation accuracy:63.64%
# Epoch 485: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 485 --- loss:0.011, Epoch accuracy:97.56%, Validation loss:1.840, Validation accuracy:62.94%
# Epoch 486: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 486 --- loss:0.012, Epoch accuracy:97.56%, Validation loss:1.727, Validation accuracy:65.03%
# Epoch 487: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 487 --- loss:0.014, Epoch accuracy:97.56%, Validation loss:1.944, Validation accuracy:60.84%
# Epoch 488: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 488 --- loss:0.014, Epoch accuracy:97.56%, Validation loss:1.756, Validation accuracy:64.34%
# Epoch 489: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 489 --- loss:0.011, Epoch accuracy:97.65%, Validation loss:1.758, Validation accuracy:65.03%
# Epoch 490: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 490 --- loss:0.011, Epoch accuracy:97.56%, Validation loss:1.637, Validation accuracy:64.34%
# Epoch 491: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 491 --- loss:0.037, Epoch accuracy:96.77%, Validation loss:1.921, Validation accuracy:64.34%
# Epoch 492: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 492 --- loss:0.107, Epoch accuracy:94.33%, Validation loss:1.884, Validation accuracy:60.84%
# Epoch 493: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 493 --- loss:0.096, Epoch accuracy:94.25%, Validation loss:1.891, Validation accuracy:56.64%
# Epoch 494: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 494 --- loss:0.114, Epoch accuracy:93.90%, Validation loss:1.720, Validation accuracy:61.54%
# Epoch 495: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 495 --- loss:0.160, Epoch accuracy:92.15%, Validation loss:2.033, Validation accuracy:61.54%
# Epoch 496: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 496 --- loss:0.053, Epoch accuracy:96.34%, Validation loss:1.668, Validation accuracy:63.64%
# Epoch 497: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 497 --- loss:0.038, Epoch accuracy:96.69%, Validation loss:1.842, Validation accuracy:63.64%
# Epoch 498: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 498 --- loss:0.039, Epoch accuracy:96.77%, Validation loss:1.860, Validation accuracy:62.94%
# Epoch 499: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 499 --- loss:0.016, Epoch accuracy:97.65%, Validation loss:1.639, Validation accuracy:65.03%
# Epoch 500: iteration 34/35torch.Size([143, 1, 40, 282])
# torch.Size([143])
# torch.Size([143]) pred_shape
# torch.Size([143]) Y_shape
#
# Epoch 500 --- loss:0.021, Epoch accuracy:97.38%, Validation loss:1.792, Validation accuracy:61.54%

# %%
plt.title('Loss Curve for Parallel is All You Want Model')
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.plot(train_losses[:],'b')
plt.plot(valid_losses[:],'r')
plt.legend(['Training loss','Validation loss'])
plt.show()

# %%
# pick load folder  
load_folder = './drive/MyDrive/content/checkpoints'  

# pick the epoch to load
epoch = '429'
model_name = f'parallel_all_you_wantFINAL-{epoch}.pkl'

# make full load path
load_path = os.path.join(load_folder, model_name)

## instantiate empty model and populate with params from binary 
model = parallel_all_you_want(len(emotions_dict))
load_checkpoint(optimizer, model, load_path)

print(f'Loaded model from {load_path}')
# Out:
# Loaded model from ./drive/MyDrive/content/checkpoints/parallel_all_you_wantFINAL-429.pkl

# %%
# reinitialize validation function with model from chosen checkpoint
validate = make_validate_fnc(model,criterion)

# Convert 4D test feature set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
# Convert 4D test label set array to tensor and move to GPU
y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function we defined
test_loss, test_acc, predicted_emotions = validate(X_test_tensor,y_test_tensor)

print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# torch.Size([150]) pred_shape
# torch.Size([150]) Y_shape
# Test accuracy is 64.00%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# because model tested on GPU, move prediction tensor to CPU then convert to array
predicted_emotions = predicted_emotions.cpu().numpy()
# use labels from test set
emotions_groundtruth = y_test

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in emotions_dict.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()
